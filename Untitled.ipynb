# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
anime_df = pd.read_csv('anime_scraper/anime_reviews.csv')
anime_df.head(20)
# Out:
#           show_title                                             review  \
# 0   my-hero-academia  It is Here! This is the future of the Shonen g...
# 1   my-hero-academia  SHORT VERSION: This is one of the most thrilli...
# 2   my-hero-academia  Had you ever found your favorite anime was end...
# 3   my-hero-academia  Potential SpoilersMinor spoilers from Season 1...
# 4   my-hero-academia  Ok so I kept saying I wouldn't watch this show...
# 5   my-hero-academia  I was browsing C.R. for kicks and I saw this o...
# 6   my-hero-academia  If "X-men" and "Sky High" had a Japanese love-...
# 7   my-hero-academia  Does an anime have to be completely original, ...
# 8   my-hero-academia  I admit, I was extremely skeptical about this ...
# 9   my-hero-academia  I got my brother, who doesn't like anime, to g...
# 10  my-hero-academia  i went to store and started walking down the p...
# 11  my-hero-academia  My Hero Academia.This series has sat in my que...
# ...

# %%
my_hero_df = anime_df.loc[anime_df['show_title'] == 'my-hero-academia']
my_hero_df
# Out:
#           show_title                                             review  \
# 0   my-hero-academia  It is Here! This is the future of the Shonen g...
# 1   my-hero-academia  SHORT VERSION: This is one of the most thrilli...
# 2   my-hero-academia  Had you ever found your favorite anime was end...
# 3   my-hero-academia  Potential SpoilersMinor spoilers from Season 1...
# 4   my-hero-academia  Ok so I kept saying I wouldn't watch this show...
# ..               ...                                                ...
# 83  my-hero-academia  This is amazing this is amazing this is amazin...
# 84  my-hero-academia  my hero academia is an amazing show! from the ...
# 85  my-hero-academia  gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8gr8g...
# 86  my-hero-academia  wow! this is amazing! wow! this is amazing! wo...
# 87  my-hero-academia  I remember first hearing about MHA back in mid...
#
#     rating
# 0      5.0
# 1      5.0
# 2      5.0
# 3      5.0
# 4      5.0
# ..     ...
# 83     5.0
# ...
